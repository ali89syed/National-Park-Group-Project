# %%
#imported national park database
import urllib.request, json
import requests
import os
import csv
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import folium


# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# Configure API request
#endpoint = "https://developer.nps.gov/api/v1/parks?&q=Cabrillo&api_key=01eq5duLdK1dQqdvhfwlrUouoTSqL8LKKK45w2F8"

# %%
national_parks_usa_FALL_to_load = "C:/Users/ali89/Downloads/top10parks_by_Fall.csv"
national_parks_usa_WINTER_to_load = "C:/Users/ali89/Downloads/top10parks_by_Winter.csv"


# Read the Mouse and Drug Data and the Clinical Trial Data

national_parks_usa_FALL = pd.read_csv(national_parks_usa_FALL_to_load)
national_parks_usa_WINTER = pd.read_csv(national_parks_usa_WINTER_to_load)

# %%
national_parks_usa_WINTER
# Out:
#                                          Park Date of Review  Rating 1,3,5,4  \
# 0                  Arches National Park, Utah    Dec 10,2017               5
# 1                  Arches National Park, Utah    Feb 26,2017               5
# 2                  Arches National Park, Utah     Ja 23,2017               5
# 3                  Arches National Park, Utah     Dec 3,2017               5
# 4                  Arches National Park, Utah    Jan 23,2017               5
# 5     Mount Rainier Natioanl Park, Washington    Dec 29,2017               5
# 6     Mount Rainier Natioanl Park, Washington     Dec 7,2017               5
# 7     Mount Rainier Natioanl Park, Washington    Feb 26,2017               5
# 8     Mount Rainier Natioanl Park, Washington    Jan 15,2017               5
# 9     Mount Rainier Natioanl Park, Washington     Jan 5,2017               5
# 10           Bryce Canyon National Park, Utah    Dec 26,2017               5
# ...

# %%
# Configure API request
#endpoint = "https://developer.nps.gov/api/v1/parks?&q=Mount Rainier&api_key=01eq5duLdK1dQqdvhfwlrUouoTSqL8LKKK45w2F8"

gkey = "AIzaSyCF35R7eLr--a0J4_MTJ9ryGIRQiVZgTJg"

# Target city
target_park = "Bryce Canyon"

# Build the endpoint URL
target_url = "https://maps.googleapis.com/maps/api/geocode/json?" \
    "address=%s&key=%s" % (target_park, gkey)
target_url
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?address=Bryce Canyon&key=AIzaSyCF35R7eLr--a0J4_MTJ9ryGIRQiVZgTJg'

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Bryce Canyon National Park', 'short_name': 'Bryce Canyon National Park', 'types': ['establishment', 'park', 'point_of_interest']}, {'long_name': 'Utah', 'short_name': 'UT', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Bryce Canyon National Park, Utah, USA', 'geometry': {'location': {'lat': 37.5930377, 'lng': -112.1870895}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 37.7086346, 'lng': -112.0905355}, 'southwest': {'lat': 37.4381249, 'lng': -112.2660916}}}, 'place_id': 'ChIJLevDAsZrNYcRBm2svvvY6Ws', 'plus_code': {'compound_code': 'HRV7+65 Tropic, Utah, United States', 'global_code': '8599HRV7+65'}, 'types': ['establishment', 'park', 'point_of_interest']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Bryce Canyon National Park",
#                     "short_name": "Bryce Canyon National Park",
#                     "types": [
#                         "establishment",
#                         "park",
#                         "point_of_interest"
#                     ]
#                 },
#                 {
#                     "long_name": "Utah",
#                     "short_name": "UT",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
# ...

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print("%s: %s, %s" % (target_city, lat, lng))
# Out:
# Bryce Canyon: 37.5930377, -112.1870895

# %%
bosiemap = folium.Map(location=[lat,lng])
marker = folium.Marker([lat,lng], popup='Welcome to Zion').add_to(bosiemap)

bosiemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
